# %% [markdown]
# # Cleaning the dataset from spotify API containing hit songs (1970-2020)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/modern_albums.csv')

# %%
df.head()
# Out:
#                        id                   name     artist  popularity  \
# 0  2YpeDb67231RjR0MgVLzsG  Old Town Road - Remix  Lil Nas X          79
# 1  6fTt0CH2t0mdeB2N9XFG5r                 Panini  Lil Nas X          62
# 2  1ABQT5SxlUTNapSbSzblGx      F9mily (You & Me)  Lil Nas X          48
# 3  3qIV7Rnj3ZxLs2JcLPUbFV                Kick It  Lil Nas X          53
# 4  4ak7xjvBeBOcJGWFDX9w5n                  Rodeo  Lil Nas X          67
#
#    explicit  energy    tempo  positiveness  danceability  acousticness  \
# 0     False   0.619  136.041         0.639         0.878        0.0533
# 1     False   0.594  153.848         0.475         0.703        0.3420
# 2     False   0.534  170.054         0.408         0.556        0.0190
# 3      True   0.484  151.878         0.523         0.739        0.1380
# 4      True   0.679  140.081         0.657         0.706        0.1390
#
#    instrumentalness  loudness  mode  speechiness  duration_ms  key album_name  \
# 0           0.00000    -5.560     1       0.1020       157067    6       7 EP
# 1           0.00000    -6.146     0       0.0752       114893    5       7 EP
# 2           0.00063    -7.750     1       0.0332       162720    0       7 EP
# 3           0.00000    -9.646     1       0.2260       141987    9       7 EP
# 4           0.00007    -5.614     1       0.0324       158707    9       7 EP
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# <br>

# %% [markdown]
# ## Cleaning Summary (TLDR)

# %% [markdown]
# - Removed column "instrumentalness" due to high percentage of missing values
# - Filtered out songs with a popularity score less than 20
# - Renamed column "duration_ms" to "duration_minutes" and converted the values from milliseconds to minutes
# - Mapped "key" column values from integers (0-11) to their respective musical keys (0 to C, 1 to Csharp/Dflat, etc)
# - Updated "mode" column to represent 'Major' or 'Minor' instead of binary values (1 or 0).

# %% [markdown]
# <br>

# %% [markdown]
# ## 1. Removing columns that contains too many nulls or zeros

# %% [markdown]
# ### Instrumentalness

# %% [markdown]
# I noticed from just looking at the head of the dataframe that the instrumentalness column does not look right, lets see how many 0 values it holds

# %%
instrumentalness_zeros = df[df['instrumentalness'] == 0]

# %%
instrumentalness_zeros.shape[0]
# Out:
# 434

# %%
(1844/5000) * 100
# Out:
# 36.88

# %% [markdown]
# As there is about 37% values missing from this column, I want to drop it completely

# %%
df.drop('instrumentalness', axis=1, inplace=True)

# %% [markdown]
# ### Speechiness

# %%
low_speechiness = df[df['speechiness'] < 0.3]
low_speechiness.shape[0]
# Out:
# 688

# %% [markdown]
# Considering that API documentation states that values below 0.33 "represent music and other non-speech-like tracks", I don't think it's accurate that my dataset almost only contains values way below this mark. Let's drop this attribute as well.

# %%
df.drop('speechiness', axis=1, inplace=True)

# %%
df.describe()
# Out:
#        popularity      energy       tempo  positiveness  danceability  \
# count  787.000000  787.000000  787.000000    787.000000    787.000000
# mean    56.224905    0.593872  118.116426      0.464227      0.660586
# std     16.933006    0.179837   31.851629      0.220911      0.161856
# min      0.000000    0.056100    0.000000      0.000000      0.000000
# 25%     46.000000    0.489000   94.065500      0.299500      0.571000
# 50%     57.000000    0.607000  114.986000      0.456000      0.682000
# 75%     68.000000    0.715500  140.006500      0.620000      0.775500
# max    100.000000    0.985000  207.476000      0.963000      0.968000
#
#        acousticness    loudness        mode    duration_ms         key    year
# count    787.000000  787.000000  787.000000     787.000000  787.000000   787.0
# mean       0.281243   -6.958445    0.579416  197018.196950    5.216010  2019.0
# std        0.275642    3.306684    0.493967   53428.723969    3.587382     0.0
# min        0.000199  -25.521000    0.000000   10760.000000    0.000000  2019.0
# 25%        0.054350   -8.168000    0.000000  175028.000000    2.000000  2019.0
# 50%        0.176000   -6.373000    1.000000  194810.000000    5.000000  2019.0
# 75%        0.449000   -4.986500    1.000000  219513.500000    8.000000  2019.0
# max        0.979000   -1.205000    1.000000  667707.000000   11.000000  2019.0

# %% [markdown]
# This should be it for the columns I want to remove

# %% [markdown]
# <br>

# %% [markdown]
# ## 2. Removing rows with zeroes and very low values

# %% [markdown]
# When fetching the data I noticed some messages from error handling that there were some rows that did not contain any data. I will select a column like danceability and see if it contains any zeroes.

# %%
danceability_zeros = df[df['danceability'] == 0]

# %%
danceability_zeros
# Out:
#                          id                                          name  \
# 8    0rQtoQXQfwpDW0c7Fw1NeM                                       !!!!!!!
# 97   7A5uLkZbEOzHiAlhD2Hr2L                First Stop, Arizona - Dialogue
# 103  1UR9zquKVw87PBAl5b9PDH                How Do You Hear It? - Dialogue
# 110  2YEslbHiO4TyqNv2BQ2EWJ                                SNL - Dialogue
# 417  5e4LIAQI0bClLazNf2gZV0  EXACTLY WHAT YOU RUN FROM YOU END UP CHASING
#
#                  artist  popularity  explicit  energy  tempo  positiveness  \
# 8         Billie Eilish          20     False  0.2780    0.0           0.0
# 97                 Cast           7     False  0.2300    0.0           0.0
# 103                Cast           4     False  0.1300    0.0           0.0
# 110                Cast           4     False  0.0604    0.0           0.0
# 417  Tyler, The Creator           9     False  0.4780    0.0           0.0
#
#      danceability  acousticness  loudness  mode  duration_ms  key  \
# 8             0.0         0.768   -21.630     1        13578    1
# 97            0.0         0.878   -23.413     1        10760    6
# 103           0.0         0.606   -21.347     1        14507    9
# 110           0.0         0.408   -20.782     1        13147    6
# 417           0.0         0.927   -16.569     0        14627   11
#
#                                    album_name  year
# 8    WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?  2019
# 97                  A Star Is Born Soundtrack  2019
# 103                 A Star Is Born Soundtrack  2019
# 110                 A Star Is Born Soundtrack  2019
# 417                                      IGOR  2019

# %% [markdown]
# Removing these two rows should not be a problem since it won't really affect the analysis later on.

# %%
df = df[df['danceability'] != 0]

# %% [markdown]
# I also noticed some songs that had very low popularity, since these playlists are hitlist I want to remove these outliers from the dataset. I think a popularity score like 20 is a good treshold to set.

# %%
low_pop = df[df['popularity'] <= 5]

# %%
low_pop
# Out:
#                          id                                        name  \
# 108  1OlU1rn0QOG40zQ699g3hV                             Vows - Dialogue
# 732  5PbAxxkcKnbkdozI7ZvFgZ  Tick Tock (with Clean Bandit ft. 24kGoldn)
# 733  1rzHuxpjVx8FHy93ep8Aba                   West Ten (with AJ Tracey)
# 751  71xTDzNV4aufQe6InpbjZf                       My Lover (with Not3s)
#
#            artist  popularity  explicit  energy    tempo  positiveness  \
# 108          Cast           5     False   0.264   92.748         0.169
# 732  Clean Bandit           0     False   0.704  101.022         0.950
# 733     AJ Tracey           0      True   0.823  129.986         0.867
# 751         Not3s           0     False   0.569  106.044         0.621
#
#      danceability  acousticness  loudness  mode  duration_ms  key  \
# 108         0.789         0.711   -23.195     0        17933    0
# 732         0.778         0.385    -3.903     1       178200    0
# 733         0.843         0.318    -4.904     0       213693   10
# 751         0.823         0.188    -7.112     0       192627    6
#
#                     album_name  year
# 108  A Star Is Born Soundtrack  2019
# 732          High Expectations  2019
# 733          High Expectations  2019
# 751          High Expectations  2019

# %%
df = df[df['popularity'] > 5]

# %% [markdown]
# Lets have a look at the summary statistics again to see if it looks better

# %%
df.describe()
# Out:
#        popularity      energy       tempo  positiveness  danceability  \
# count  778.000000  778.000000  778.000000    778.000000    778.000000
# mean    56.812339    0.596197  118.930369      0.466246      0.664072
# std     16.106571    0.177559   30.565716      0.217531      0.153508
# min      8.000000    0.056100   56.940000      0.031500      0.131000
# 25%     47.000000    0.492000   94.520500      0.306250      0.572000
# 50%     57.000000    0.609500  114.996000      0.457000      0.682000
# 75%     69.000000    0.716000  140.029500      0.620000      0.774750
# max    100.000000    0.985000  207.476000      0.963000      0.968000
#
#        acousticness    loudness        mode    duration_ms         key    year
# count    778.000000  778.000000  778.000000     778.000000  778.000000   778.0
# mean       0.277826   -6.855323    0.579692  198437.338046    5.213368  2019.0
# std        0.274092    3.071913    0.493926   51248.508605    3.582199     0.0
# min        0.000199  -25.521000    0.000000   19133.000000    0.000000  2019.0
# 25%        0.053800   -8.095750    0.000000  175387.250000    2.000000  2019.0
# 50%        0.173000   -6.363500    1.000000  194991.000000    5.000000  2019.0
# 75%        0.442000   -4.985750    1.000000  220283.750000    8.000000  2019.0
# max        0.979000   -1.205000    1.000000  667707.000000   11.000000  2019.0

# %% [markdown]
# <br>

# %% [markdown]
# ## 3. Converting the duration of songs (milliseconds to minutes)

# %% [markdown]
# Since looking at milliseconds is a bit weird I'd like to convert this value to minutes, something that everyone understands.

# %%
df = df.rename(columns={'duration_ms': 'duration_minutes'})

df['duration_minutes'] = df['duration_minutes'] / 60000

# %% [markdown]
# Let's also round up these minutes

# %%
df['duration_minutes'] = df['duration_minutes'].round(1)

# %%
df['duration_minutes'].head(3)
# Out:
# 0    2.6
# 1    1.9
# 2    2.7
# Name: duration_minutes, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# ## 4. Changing keys from integers to strings

# %% [markdown]
# Next up I would like to change the name of they keys, spotify name these using Pitch Class notation.

# %% [markdown]
# <img src="https://davidkulma.com/wp-content/uploads/2016/08/Integer-Circle.001.png" width="300"/>

# %%
key_mapping = {
    0: "C",
    1: "Csharp/Dflat",
    2: "D",
    3: "Dsharp/Eflat",
    4: "E",
    5: "F",
    6: "Fsharp/Gflat",
    7: "G",
    8: "Gsharp/Aflat",
    9: "A",
    10: "Asharp/Bflat",
    11: "B"
}

# %%
df['key'] = df['key'].map(key_mapping)

# %%
df['key'].head()
# Out:
# 0    Fsharp/Gflat
# 1               F
# 2               C
# 3               A
# 4               A
# Name: key, dtype: object

# %% [markdown]
# That looks better and much easier to follow

# %%
df
# Out:
#                          id                         name  \
# 0    2YpeDb67231RjR0MgVLzsG        Old Town Road - Remix
# 1    6fTt0CH2t0mdeB2N9XFG5r                       Panini
# 2    1ABQT5SxlUTNapSbSzblGx            F9mily (You & Me)
# 3    3qIV7Rnj3ZxLs2JcLPUbFV                      Kick It
# 4    4ak7xjvBeBOcJGWFDX9w5n                        Rodeo
# ..                      ...                          ...
# 782  0OAyZn9pGuuL2FJih1PM58                  Billie Jean
# 783  5h66wqaGklsSa8eSxTwcJT  4 Min Convo (Favorite Song)
# 784  7MuhbSNErlmQAGRzhnnIjT                         Odee
# 785  76vviJBqmRdMMb9u9npgfj          Pull Up (feat. NAV)
# 786  1oLSje4Ot5qRUq8FqYeXOl       Don’t Feel Like Crying
#
#                      artist  popularity  explicit  energy    tempo  \
# 0                 Lil Nas X          79     False   0.619  136.041
# 1                 Lil Nas X          62     False   0.594  153.848
# 2                 Lil Nas X          48     False   0.534  170.054
# 3                 Lil Nas X          53      True   0.484  151.878
# 4                 Lil Nas X          67      True   0.679  140.081
# ..                      ...         ...       ...     ...      ...
# 782  A Boogie Wit da Hoodie          52      True   0.536  139.961
# 783  A Boogie Wit da Hoodie          59      True   0.650   91.053
# 784  A Boogie Wit da Hoodie          58      True   0.480   86.049
# 785  A Boogie Wit da Hoodie          50      True   0.370  149.950
# 786                  Sigrid          46     False   0.814  119.964
#
#      positiveness  danceability  acousticness  loudness  mode  \
# 0           0.639         0.878        0.0533    -5.560     1
# 1           0.475         0.703        0.3420    -6.146     0
# 2           0.408         0.556        0.0190    -7.750     1
# 3           0.523         0.739        0.1380    -9.646     1
# 4           0.657         0.706        0.1390    -5.614     1
# ..            ...           ...           ...       ...   ...
# 782         0.375         0.830        0.0919    -6.324     0
# 783         0.658         0.705        0.3590    -5.654     0
# 784         0.293         0.854        0.2080    -7.388     0
# 785         0.557         0.828        0.4870    -7.446     0
# 786         0.715         0.749        0.1560    -3.769     0
#
#      duration_minutes           key              album_name  year
# 0                 2.6  Fsharp/Gflat                    7 EP  2019
# 1                 1.9             F                    7 EP  2019
# 2                 2.7             C                    7 EP  2019
# 3                 2.4             A                    7 EP  2019
# 4                 2.6             A                    7 EP  2019
# ..                ...           ...                     ...   ...
# 782               2.3             E              Hoodie SZN  2019
# 783               4.3             G              Hoodie SZN  2019
# 784               2.7             A              Hoodie SZN  2019
# 785               3.2             G              Hoodie SZN  2019
# 786               2.6             F  Don't Feel Like Crying  2019
#
# [778 rows x 16 columns]

# %% [markdown]
# <br>

# %% [markdown]
# ## 5. Changing Mode from integers to strings

# %% [markdown]
# Currently in the mode column, 1 represents Major and 0 represents Minor

# %%
mode_mapping = {
    0: "Minor",
    1: "Major"
}

# %%
df['mode'] = df['mode'].map(mode_mapping)

# %%
df['mode'].head()
# Out:
# 0    Major
# 1    Minor
# 2    Major
# 3    Major
# 4    Major
# Name: mode, dtype: object

# %% [markdown]
# That's about it, one last thing I want to do is to remove the id column as well, I kept it their if I ever needed to fetch any additional data on the songs but it was not of much help.

# %% [markdown]
# <br>

# %% [markdown]
# ## 6. Dropping the id column

# %%
df.drop('id', axis=1, inplace=True)

# %% [markdown]
# <br>

# %% [markdown]
# ## 7. Having a look at the clean dataframe

# %%
df
# Out:
#                             name                  artist  popularity  \
# 0          Old Town Road - Remix               Lil Nas X          79
# 1                         Panini               Lil Nas X          62
# 2              F9mily (You & Me)               Lil Nas X          48
# 3                        Kick It               Lil Nas X          53
# 4                          Rodeo               Lil Nas X          67
# ..                           ...                     ...         ...
# 782                  Billie Jean  A Boogie Wit da Hoodie          52
# 783  4 Min Convo (Favorite Song)  A Boogie Wit da Hoodie          59
# 784                         Odee  A Boogie Wit da Hoodie          58
# 785          Pull Up (feat. NAV)  A Boogie Wit da Hoodie          50
# 786       Don’t Feel Like Crying                  Sigrid          46
#
#      explicit  energy    tempo  positiveness  danceability  acousticness  \
# 0       False   0.619  136.041         0.639         0.878        0.0533
# 1       False   0.594  153.848         0.475         0.703        0.3420
# 2       False   0.534  170.054         0.408         0.556        0.0190
# 3        True   0.484  151.878         0.523         0.739        0.1380
# 4        True   0.679  140.081         0.657         0.706        0.1390
# ..        ...     ...      ...           ...           ...           ...
# 782      True   0.536  139.961         0.375         0.830        0.0919
# 783      True   0.650   91.053         0.658         0.705        0.3590
# 784      True   0.480   86.049         0.293         0.854        0.2080
# 785      True   0.370  149.950         0.557         0.828        0.4870
# 786     False   0.814  119.964         0.715         0.749        0.1560
#
#      loudness   mode  duration_minutes           key              album_name  \
# 0      -5.560  Major               2.6  Fsharp/Gflat                    7 EP
# 1      -6.146  Minor               1.9             F                    7 EP
# 2      -7.750  Major               2.7             C                    7 EP
# 3      -9.646  Major               2.4             A                    7 EP
# 4      -5.614  Major               2.6             A                    7 EP
# ..        ...    ...               ...           ...                     ...
# 782    -6.324  Minor               2.3             E              Hoodie SZN
# 783    -5.654  Minor               4.3             G              Hoodie SZN
# 784    -7.388  Minor               2.7             A              Hoodie SZN
# 785    -7.446  Minor               3.2             G              Hoodie SZN
# 786    -3.769  Minor               2.6             F  Don't Feel Like Crying
#
#      year
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# ..    ...
# 782  2019
# 783  2019
# 784  2019
# 785  2019
# 786  2019
#
# [778 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 778 entries, 0 to 786
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              778 non-null    object
#  1   artist            778 non-null    object
#  2   popularity        778 non-null    int64
#  3   explicit          778 non-null    bool
#  4   energy            778 non-null    float64
#  5   tempo             778 non-null    float64
#  6   positiveness      778 non-null    float64
#  7   danceability      778 non-null    float64
#  8   acousticness      778 non-null    float64
#  9   loudness          778 non-null    float64
#  10  mode              778 non-null    object
#  11  duration_minutes  778 non-null    float64
#  12  key               778 non-null    object
#  13  album_name        778 non-null    object
#  14  year              778 non-null    int64
# dtypes: bool(1), float64(7), int64(2), object(5)
# memory usage: 91.9+ KB

# %%
df.describe()
# Out:
#        popularity      energy       tempo  positiveness  danceability  \
# count  778.000000  778.000000  778.000000    778.000000    778.000000
# mean    56.812339    0.596197  118.930369      0.466246      0.664072
# std     16.106571    0.177559   30.565716      0.217531      0.153508
# min      8.000000    0.056100   56.940000      0.031500      0.131000
# 25%     47.000000    0.492000   94.520500      0.306250      0.572000
# 50%     57.000000    0.609500  114.996000      0.457000      0.682000
# 75%     69.000000    0.716000  140.029500      0.620000      0.774750
# max    100.000000    0.985000  207.476000      0.963000      0.968000
#
#        acousticness    loudness  duration_minutes    year
# count    778.000000  778.000000        778.000000   778.0
# mean       0.277826   -6.855323          3.306812  2019.0
# std        0.274092    3.071913          0.853620     0.0
# min        0.000199  -25.521000          0.300000  2019.0
# 25%        0.053800   -8.095750          2.900000  2019.0
# 50%        0.173000   -6.363500          3.250000  2019.0
# 75%        0.442000   -4.985750          3.700000  2019.0
# max        0.979000   -1.205000         11.100000  2019.0

# %% [markdown]
# ## Exporting to csv

# %%
df.to_csv('../data/modern_albums_cleaned.csv', index=False)
